# %%
#Using Pillow Library

import PIL  
print("Pillow Version", PIL.__version__)
# Out:
# Pillow Version 8.4.0

# %%
#load and show the image with pillow
from PIL import Image
image=Image.open('bird.jpg')
print(image.format)
print(image.size)
print(image.mode)
# Out:
# JPEG
# (700, 484)
# RGB

# %%
#using matplotlib library

from matplotlib import image
from matplotlib import pyplot
#load image as pixel array
image=image.imread('bird.jpg')
#summarize the shape of pixel array
print(image.dtype)
print(image.shape)
#display the array of pixels as an image
pyplot.imshow(image)
pyplot.show()
# Out:
# uint8
# (484, 700, 3)

# %% [markdown]
# #we get a report on the data type of the array. In this case, it is 8-bit unsigned integers.
# #The shape of the array is 800 pixels wide by 450 pixels high and 3 denotes color channels for red, green, and blue.

# %%
# Convert to NumPy Array and Back#

from PIL import Image
from numpy import asarray
# load the image
image = Image.open('bird.jpg')
# convert image to numpy array
data = asarray(image)
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
# summarize shape
print(data.shape)
# Out:
# (484, 700, 3)

# %%
# create Pillow image
image2 = Image.fromarray(data)
print(type(image2))
# Out:
# <class 'PIL.Image.Image'>

# %%
# summarize image details
print(image2.mode)
print(image2.size)
# Out:
# RGB
# (700, 484)

# %%
print(data)
# Out:
# [[[119 148  84]
#   [119 148  84]
#   [118 146  85]
#   ...
#   [ 64  89  47]
#   [ 66  89  47]
#   [ 66  89  47]]
#
#  [[119 148  84]
#   [118 147  83]
#   [118 146  85]
#   ...
#   [ 64  89  47]
#   [ 64  89  47]
#   [ 66  89  47]]
#
#  [[118 147  83]
#   [118 147  83]
#   [118 146  85]
#   ...
#   [ 64  89  47]
#   [ 64  89  47]
#   [ 64  89  47]]
#
#  ...
#
#  [[171 191  92]
#   [171 191  92]
#   [171 191  92]
#   ...
#   [129 146  94]
#   [131 145  94]
#   [131 145  94]]
#
#  [[171 191  92]
#   [171 191  92]
#   [171 191  92]
#   ...
#   [128 145  93]
#   [130 144  93]
#   [130 144  93]]
#
#  [[171 191  92]
#   [171 191  92]
#   [171 191  92]
#   ...
#   [127 144  92]
#   [129 143  92]
#   [130 144  93]]]

# %%
#converting image to Gray scale

import numpy as np
from PIL import Image

im = np.array(Image.open('bird.jpg').convert('L')) #you can pass multiple arguments in single line
print(type(im))

gr_im= Image.fromarray(im).save('new_bird.jpg')
# Out:
# <class 'numpy.ndarray'>

# %%
#resizing the images

load_img_rz = np.array(Image.open('bird.jpg').resize((200,200)))
Image.fromarray(load_img_rz).save('re_bird.jpg')
print("After resizing:",load_img_rz.shape)
# Out:
# After resizing: (200, 200, 3)

# %%
#trimming image

im = np.array(Image.open('bird.jpg'))

print("Before trimming:",im.shape)

im_trim = im[128:384, 128:384]
print("After trimming:",im_trim.shape)

Image.fromarray(im_trim).save('trim_bird.jpg')
# Out:
# Before trimming: (484, 700, 3)
# After trimming: (256, 256, 3)

# %%
#Loading an Image With Keras API

from keras.preprocessing.image import load_img
import warnings
#load the image
img=load_img('bird.jpg')
print(type(img))
print(img.format)
print(img.size)
print(img.mode)
#show the image
img.show()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# (700, 484)
# RGB

# %%
# example of converting an image with the Keras API
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
# load the image
img = load_img('bird.jpg')
print("Orignal:" ,type(img))

# convert to numpy array
img_array = img_to_array(img)
print("NumPy array info:") 
print(type(img_array))    

print("type:",img_array.dtype)
print("shape:",img_array.shape)
# convert back to image

img_pil = array_to_img(img_array)
print("converting NumPy array:",type(img_pil))
# Out:
# Orignal: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# NumPy array info:
# <class 'numpy.ndarray'>
# type: float32
# shape: (484, 700, 3)
# converting NumPy array: <class 'PIL.Image.Image'>

# %%
# example of saving an image with the Keras API
from keras.preprocessing.image import load_img
from keras.preprocessing.image import save_img
# save the image with a new filename
save_img('Keras_bird.png', img_array)
# load the image to confirm it was saved correctly
img = load_img('Keras_bird.png')
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
img.show()
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>
# PNG
# RGB
# (700, 484)
